# %%
#Build out teams_user_activity table in the Lakehouse

from pyspark.sql.types import StructType, StructField, IntegerType, StringType, DateType, BooleanType, DecimalType
schema = StructType([
    StructField("Report_Refresh_Date", DateType(), True),
    StructField("User_Principal_Name", StringType(), True),
    StructField("Last_Activity_Date", DateType(), True),
    StructField("Team_Chat_Message_Count", IntegerType(), True),
    StructField("Private_Chat_Message_Count", IntegerType(), True),
    StructField("Call_Count", IntegerType(), True),
    StructField("Meeting_Count", IntegerType(), True),
    StructField("Meetings_Organized_Count", IntegerType(), True),
    StructField("Meetings_Attended_Count", IntegerType(), True),
    StructField("Ad_Hoc_Meetings_Organized_Count", IntegerType(), True),
    StructField("Ad_Hoc_Meetings_Attended_Count", IntegerType(), True),
    StructField("Scheduled_One-time_Meetings_Organized_Count", IntegerType(), True),
    StructField("Scheduled_One-time_Meetings_Attended_Count", IntegerType(), True),
    StructField("Scheduled_Recurring_Meetings_Organized_Count", IntegerType(), True),
    StructField("Scheduled_Recurring_Meetings_Attended_Count", IntegerType(), True),
    StructField("Audio_Duration_In_Seconds", IntegerType(), True),
    StructField("Video_Duration_In_Seconds", IntegerType(), True),
    StructField("Screen_Share_Duration_In_Seconds", IntegerType(), True),
    StructField("Has_Other_Action", BooleanType(), True),
    StructField("Urgent_Messages", IntegerType(), True),
    StructField("Post_Messages", IntegerType(), True),
    StructField("Reply_Messages", IntegerType(), True),
    StructField("Channel_Post_Made", BooleanType(), True),
    StructField("Private_Chat_Sent", BooleanType(), True),
    StructField("Call_Made", BooleanType(), True),
    StructField("Meeting_Attended", BooleanType(), True),
    StructField("Collab_Score", DecimalType(), True)
])
df = spark.createDataFrame([], schema)
df.write.format("delta").saveAsTable("teams_user_activity")
# Out:
# StatementMeta(, 2f92a537-983d-4d74-a17d-a96289469eed, 13, Finished, Available, Finished)

# %%
#Build out onedrive_user_activity table in the Lakehouse

from pyspark.sql.types import StructType, StructField, IntegerType, StringType, DateType, BooleanType, DecimalType
schema = StructType([
    StructField("Report_Refresh_Date", DateType(), True),
    StructField("User_Principal_Name", StringType(), True),
    StructField("Last_Activity_Date", DateType(), True),
    StructField("Viewed_Or_Edited_File_Count", IntegerType(), True),
    StructField("Synced_File_Count", IntegerType(), True),
    StructField("Shared_Internally_File_Count", IntegerType(), True),
    StructField("Shared_Externally_File_Count", IntegerType(), True),
    StructField("Viewed_or_Edited_Files", BooleanType(), True),
    StructField("Synced_File", BooleanType(), True),
    StructField("Shared_File_Internally", BooleanType(), True),
    StructField("Shared_File_Externally", BooleanType(), True),
    StructField("Collab_Score", DecimalType(), True)
])
df = spark.createDataFrame([], schema)
df.write.format("delta").saveAsTable("onedrive_user_activity")
# Out:
# StatementMeta(, 2f92a537-983d-4d74-a17d-a96289469eed, 14, Finished, Available, Finished)

# %%
#Build out sharepoint_user_activity table in the Lakehouse

from pyspark.sql.types import StructType, StructField, IntegerType, StringType, DateType, BooleanType, DecimalType
schema = StructType([
    StructField("Report_Refresh_Date", DateType(), True),
    StructField("User_Principal_Name", StringType(), True),
    StructField("Last_Activity_Date", DateType(), True),
    StructField("Viewed_Or_Edited_File_Count", IntegerType(), True),
    StructField("Synced_File_Count", IntegerType(), True),
    StructField("Shared_Internally_File_Count", IntegerType(), True),
    StructField("Shared_Externally_File_Count", IntegerType(), True),
    StructField("Visted_Page_Count", IntegerType(), True),
    StructField("Visited_Page", BooleanType(), True),
    StructField("Viewed_or_Edited_Files", BooleanType(), True),
    StructField("Synced_File", BooleanType(), True),
    StructField("Shared_File_Internally", BooleanType(), True),
    StructField("Shared_File_Externally", BooleanType(), True),
    StructField("Collab_Score", DecimalType(), True)
])
df = spark.createDataFrame([], schema)
df.write.format("delta").saveAsTable("sharepoint_user_activity")
# Out:
# StatementMeta(, 2f92a537-983d-4d74-a17d-a96289469eed, 15, Finished, Available, Finished)

# %%
#Build out viva_engage_user_activity table in the Lakehouse

from pyspark.sql.types import StructType, StructField, IntegerType, StringType, DateType, BooleanType, DecimalType
schema = StructType([
    StructField("Report_Refresh_Date", DateType(), True),
    StructField("User_Principal_Name", StringType(), True),
    StructField("Last_Activity_Date", DateType(), True),
    StructField("Posted_Count", IntegerType(), True),
    StructField("Read_Count", IntegerType(), True),
    StructField("Liked_Count", IntegerType(), True),
    StructField("Posted", BooleanType(), True),
    StructField("Read_Posts", BooleanType(), True),
    StructField("Liked_Posts", BooleanType(), True),
    StructField("Collab_Score", DecimalType(), True)
])
df = spark.createDataFrame([], schema)
df.write.format("delta").saveAsTable("viva_engage_user_activity")
# Out:
# StatementMeta(, 2f92a537-983d-4d74-a17d-a96289469eed, 16, Finished, Available, Finished)

# %%
#Build out copilot_data table in the Lakehouse

from pyspark.sql.types import StructType, StructField, IntegerType, StringType, DateType, BooleanType
schema = StructType([
    StructField("Report_Refresh_Date", DateType(), True),
    StructField("User_Principal_Name", StringType(), True),
    StructField("Last_Activity_Date", DateType(), True),
    StructField("Copilot", StringType(), True),
    StructField("Activity_Flag", BooleanType(), True)
])
df = spark.createDataFrame([], schema)
df.write.format("delta").saveAsTable("copilot_data")
# Out:
# StatementMeta(, 2f92a537-983d-4d74-a17d-a96289469eed, 7, Finished, Available, Finished)

# %%
#Build out copilot_last_activity table in the Lakehouse

from pyspark.sql.types import StructType, StructField, IntegerType, StringType, DateType, BooleanType
schema = StructType([
    StructField("Report_Refresh_Date", DateType(), True),
    StructField("User_Principal_Name", StringType(), True),
    StructField("Last_Activity_Date", DateType(), True),
    StructField("Activity_Label", StringType(), True)
])
df = spark.createDataFrame([], schema)
df.write.format("delta").saveAsTable("copilot_last_activity")
# Out:
# StatementMeta(, 2f92a537-983d-4d74-a17d-a96289469eed, 8, Finished, Available, Finished)

# %%
#Build out graph_users table in the Lakehouse

from pyspark.sql.types import StructType, StructField, IntegerType, StringType, DateType, BooleanType
schema = StructType([
    StructField("display_name", StringType(), True),
    StructField("User_Principal_Name", StringType(), True),
    StructField("id", StringType(), True),
    StructField("mail", StringType(), True),
    StructField("first_name", StringType(), True),
    StructField("last_name", StringType(), True),
    StructField("job_title", StringType(), True),
    StructField("department", StringType(), True),
    StructField("company", StringType(), True),
    StructField("office_location", StringType(), True),
    StructField("account_enabled", BooleanType(), True),
    StructField("user_type", StringType(), True),
    StructField("employee_type", StringType(), True),
    StructField("manager_name", StringType(), True),
    StructField("manager_email", StringType(), True)
])
df = spark.createDataFrame([], schema)
df.write.format("delta").saveAsTable("graph_users")
# Out:
# StatementMeta(, 2f92a537-983d-4d74-a17d-a96289469eed, 12, Finished, Available, Finished)

# %%
#Build out date_table table in the Lakehouse

from pyspark.sql.types import StructType, StructField, IntegerType, StringType, DateType, BooleanType
schema = StructType([
    StructField("date", DateType(), True),
    StructField("year", IntegerType(), True),
    StructField("month", IntegerType(), True),
    StructField("day", IntegerType(), True),
    StructField("month_name", StringType(), True),
    StructField("day_name", StringType(), True)
])
df = spark.createDataFrame([], schema)
df.write.format("delta").saveAsTable("date_table")
# Out:
# StatementMeta(, 2f92a537-983d-4d74-a17d-a96289469eed, 11, Finished, Available, Finished)

# %%
#Build out licensing_data table in the Lakehouse

from pyspark.sql.types import StructType, StructField, IntegerType, StringType, DateType, BooleanType
schema = StructType([

    StructField("User_Principal_Name", StringType(), True),
    StructField("assigned_products", StringType(), True)
])
df = spark.createDataFrame([], schema)
df.write.format("delta").saveAsTable("licensing_data")
# Out:
# StatementMeta(, 3de4d53e-f8aa-47f8-b418-ca7c41a8b105, 3, Finished, Available, Finished)

# %%
#Build out collaboration_levels table in the Lakehouse

from pyspark.sql.types import StructType, StructField, StringType

schema = StructType([

    StructField("collaboration_level", StringType(), True)
])
df = spark.createDataFrame([], schema)
df.write.format("delta").saveAsTable("collaboration_levels")
# Out:
# StatementMeta(, 610ae091-4d20-41a3-a3aa-37c84c11155c, 12, Finished, Available, Finished)

# %%
#Create Collaboration Levels to be added to the model

data = [{"collaboration_level": 'Collaboration Influencer'}, {"collaboration_level": 'Team Collaborator'}, {"collaboration_level": 'Individual Collaborator'}]
df = spark.createDataFrame(data)

df.write.format("delta").mode("overwrite").save("Tables/collaboration_levels")
# Out:
# StatementMeta(, 610ae091-4d20-41a3-a3aa-37c84c11155c, 22, Finished, Available, Finished)
# +--------------------+
# | collaboration_level|
# +--------------------+
# |Collaboration Inf...|
# |   Team Collaborator|
# |Individual Collab...|
# +--------------------+

# %%
#Validate collaboration_levels was properly updates

df = spark.sql("SELECT * FROM collaboration_levels")
display(df)
# Out:
# StatementMeta(, 610ae091-4d20-41a3-a3aa-37c84c11155c, 23, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 5a9f0d38-7cda-44cc-9d77-74124103aa87)
